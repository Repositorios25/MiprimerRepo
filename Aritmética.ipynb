# %%
# En la siguiente linea importamos la funcion raiz cuadrada.
# Revisa otras funciones matemáticas
# en https://docs.python.org/3/library/math.html
from math import sqrt

#n = float(input('Ingrese un numero: '))
#print('n = ', n)
#print('5 por n = ', 5*n)
#print('n dividido dos = ', n/2)
#print('raiz cuadrada de n = ', sqrt(n))

#solución cuadrática

from math import sqrt

print("solución cuadrática tipo ax**2 + bx + c=0 con python")
a = float(input('Ingrese valor de a: '))
b = float(input('Ingrese valor de b: '))
c = float(input('Ingrese valor de c: '))

x_1=(-b+ sqrt (b**2-(4*a*c)))/(2*a)

print("la solución 1 tomando el signo positivo es :", x_1)

x_2=(-b-sqrt(b**2-(4*a*c)))/(2*a)

print("la solución 2 tomando el signo negativo es:", x_2)
# Out:
# solución cuadrática tipo ax**2 + bx + c=0 con python
# Ingrese valor de a: 5
# Ingrese valor de b: 9
# Ingrese valor de c: -4
# la solución 1 tomando el signo positivo es : 0.368857754044952
# la solución 2 tomando el signo negativo es: -2.1688577540449523
